# %% [markdown]
# <a href="https://colab.research.google.com/github/rsekola/Projet_data/blob/master/Exploration_de_donn%C3%A9es%20avec_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("STEG_BILLING_HISTORY.csv")

# 10 premières lignes
client_0_bills = df.head(10)
print(client_0_bills)
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
# 5  train_Client_0   2017-07-17          11       1335667.0               0
# 6  train_Client_0   2018-12-07          11       1335667.0               0
# 7  train_Client_0   2019-03-19          11       1335667.0               0
# 8  train_Client_0   2011-07-22          11       1335667.0               0
# 9  train_Client_0   2011-11-22          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
print(type(client_0_bills))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.info()
print(df.shape)
categorical_cols = df.select_dtypes(include="object").columns
print(categorical_cols)
print("Nombre :", len(categorical_cols))
print(df.memory_usage(deep=True).sum() / (1024*1024), "MB")
print(df.isna().sum())

for col in df.select_dtypes(include="number").columns:
    df[col] = df[col].fillna(df[col].median())

for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].fillna(df[col].mode()[0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592110 entries, 0 to 592109
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   client_id             592110 non-null  object
#  1   invoice_date          592110 non-null  object
#  2   tarif_type            592110 non-null  int64
#  3   counter_number        592104 non-null  float64
#  4   counter_statue        592110 non-null  int64
#  5   counter_code          592110 non-null  int64
#  6   reading_remarque      591493 non-null  float64
#  7   counter_coefficient   592109 non-null  float64
#  8   consommation_level_1  592109 non-null  float64
#  9   consommation_level_2  592109 non-null  float64
#  10  consommation_level_3  592109 non-null  float64
#  11  consommation_level_4  592109 non-null  float64
#  12  old_index             592109 non-null  float64
#  13  new_index             592109 non-null  float64
# ...

# %%
print(df.describe())
# Out:
#           tarif_type  counter_number  counter_statue   counter_code  \
# count  592110.000000    5.921100e+05   592110.000000  592110.000000
# mean       20.136110    1.164013e+11        0.041587     171.850938
# std        13.476232    1.609983e+12        0.371349     133.313447
# min         8.000000    0.000000e+00        0.000000       5.000000
# 25%        11.000000    1.233830e+05        0.000000       5.000000
# 50%        11.000000    5.004730e+05        0.000000     203.000000
# 75%        40.000000    1.120834e+06        0.000000     207.000000
# max        45.000000    2.738110e+13        5.000000     600.000000
#
#        reading_remarque  counter_coefficient  consommation_level_1  \
# count     592110.000000        592110.000000         592110.000000
# mean           7.321435             1.000054            406.816836
# std            1.360186             0.019011            553.980943
# min            6.000000             0.000000              0.000000
# ...

# %%
client0_m1 = df[df["client_id"] == "train_Client_0"]
print(client0_m1.head())
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203               8.0                  1.0                  82.0
# 1           203               6.0                  1.0                1200.0
# 2           203               8.0                  1.0                 123.0
# 3           207               8.0                  1.0                 102.0
# 4           207               9.0                  1.0                 572.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df["counter_type_encoded"] = encoder.fit_transform(df["counter_type"])
print(df[["counter_type", "counter_type_encoded"]].head())
# Out:
#   counter_type  counter_type_encoded
# 0         ELEC                     0
# 1         ELEC                     0
# 2         ELEC                     0
# 3         ELEC                     0
# 4         ELEC                     0

# %%
df = df.drop(columns=["counter_statue"])
print(df.columns)
# Out:
# Index(['client_id', 'invoice_date', 'tarif_type', 'counter_number',
#        'counter_code', 'reading_remarque', 'counter_coefficient',
#        'consommation_level_1', 'consommation_level_2', 'consommation_level_3',
#        'consommation_level_4', 'old_index', 'new_index', 'months_number',
#        'counter_type', 'counter_type_encoded'],
#       dtype='object')
